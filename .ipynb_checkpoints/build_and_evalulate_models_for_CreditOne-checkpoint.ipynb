# %% [markdown]
# # Build and Evaluate Classifier for Customore Credit card defaulting

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import scipy
from math import sqrt

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns 
import pylab
# %matplotlib inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

#model metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split 

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import  accuracy_score
from sklearn.metrics import confusion_matrix

# %%
#import credit file
credit = pd.read_csv('default of credit card clients.csv', header =1)

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
#  13  BILL_AMT2                   30000 non-null  int64
#  14  BILL_AMT3                   30000 non-null  int64
#  15  BILL_AMT4                   30000 non-null  int64
#  16  BILL_AMT5                   30000 non-null  int64
#  17  BILL_AMT6                   30000 non-null  int64
#  18  PAY_AMT1                    30000 non-null  int64
#  19  PAY_AMT2                    30000 non-null  int64
#  20  PAY_AMT3                    30000 non-null  int64
#  21  PAY_AMT4                    30000 non-null  int64
#  22  PAY_AMT5                    30000 non-null  int64
#  23  PAY_AMT6                    30000 non-null  int64
#  24  default payment next month  30000 non-null  int64
# dtypes: int64(25)
# memory usage: 5.7 MB

# %%
#sample for processing
credit = credit.sample(n=2000,replace =False,random_state=1)

# %%
credit.index = credit['ID']

# %%
credit.drop('ID',axis=1,inplace=True)

# %%
credit.isnull().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
credit['SEX'].value_counts(dropna=False)
# Out:
# 2    1206
# 1     794
# Name: SEX, dtype: int64

# %%
credit['EDUCATION'].value_counts(dropna=False)
# Out:
# 2    925
# 1    715
# 3    325
# 5     18
# 4     13
# 6      4
# Name: EDUCATION, dtype: int64

# %%
credit = credit.rename(columns={'default payment next month': 'def_pay', 
                        'PAY_0': 'PAY_1'})
credit.head()
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# ID
# 10748     310000    1          3         1   32      0      0      0      0
# 12574      10000    2          3         1   49     -1     -1     -2     -1
# 29677      50000    1          2         1   28     -1     -1     -1      0
# 8857       80000    2          3         1   52      2      2      3      3
# 21099     270000    1          1         2   34      1      2      0      0
#
#        PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ID            ...
# 10748      0  ...      84373      57779      14163      8295      6000
# 12574      2  ...       1690       1138        930         0         0
# 29677     -1  ...      45975       1300      43987         0     46257
# 8857       3  ...      40748      39816      40607      3700      1600
# 21099      2  ...      22448      15490      17343         0      4000
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  def_pay
# ID
# 10748      4000      3000      1000      2000        0
# 12574      2828         0       182         0        1
# 29677      2200      1300     43987      1386        0
# 8857       1600         0      1600      1600        1
# 21099      2000         0      2000      2000        0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
credit.head()
credit.describe()
header = credit.dtypes.index
print(header)
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'def_pay'],
#       dtype='object')

# %%
#Correlation Matrix
corrMat = credit.corr()
print(corrMat)
# Out:
#            LIMIT_BAL       SEX  EDUCATION  MARRIAGE       AGE     PAY_1  \
# LIMIT_BAL   1.000000  0.040771  -0.199087 -0.139275  0.138840 -0.274978
# SEX         0.040771  1.000000   0.014441 -0.040209 -0.083535 -0.083759
# EDUCATION  -0.199087  0.014441   1.000000 -0.139183  0.161365  0.120761
# MARRIAGE   -0.139275 -0.040209  -0.139183  1.000000 -0.405739  0.024723
# AGE         0.138840 -0.083535   0.161365 -0.405739  1.000000 -0.043785
# PAY_1      -0.274978 -0.083759   0.120761  0.024723 -0.043785  1.000000
# PAY_2      -0.288998 -0.120320   0.140661  0.016416 -0.026144  0.663725
# PAY_3      -0.297679 -0.096795   0.129908  0.024036 -0.030219  0.586904
# PAY_4      -0.274531 -0.095600   0.133892  0.003675 -0.017858  0.563806
# PAY_5      -0.256782 -0.120186   0.124966  0.003836 -0.018790  0.543924
# PAY_6      -0.245735 -0.080590   0.098830  0.007402 -0.025176  0.494823
# BILL_AMT1   0.314470 -0.019495   0.047929 -0.028975  0.053550  0.169398
# BILL_AMT2   0.289101 -0.015164   0.045305 -0.026654  0.056379  0.178041
# BILL_AMT3   0.279569 -0.002091   0.027205 -0.036925  0.057617  0.135480
# BILL_AMT4   0.301401 -0.010677   0.024360 -0.027985  0.078767  0.162684
# BILL_AMT5   0.305286  0.007424   0.018253 -0.040211  0.071235  0.172668
# BILL_AMT6   0.287902 -0.000037   0.019900 -0.033541  0.062059  0.171040
# PAY_AMT1    0.230001  0.022765  -0.044262 -0.005228  0.052923 -0.084565
# PAY_AMT2    0.132230  0.024393  -0.035723 -0.030449  0.012226 -0.067116
# PAY_AMT3    0.230072  0.015070  -0.024643 -0.009521  0.070831 -0.081663
# PAY_AMT4    0.202773  0.057347  -0.037671 -0.045708  0.017653 -0.071623
# PAY_AMT5    0.205445 -0.006160  -0.040294 -0.015015  0.019201 -0.063980
# PAY_AMT6    0.230646  0.012487  -0.057705  0.007395 -0.013341 -0.068690
# def_pay    -0.178870 -0.046211   0.018963  0.017195 -0.015071  0.333589
#
#               PAY_2     PAY_3     PAY_4     PAY_5  ...  BILL_AMT4  BILL_AMT5  \
# LIMIT_BAL -0.288998 -0.297679 -0.274531 -0.256782  ...   0.301401   0.305286
# SEX       -0.120320 -0.096795 -0.095600 -0.120186  ...  -0.010677   0.007424
# EDUCATION  0.140661  0.129908  0.133892  0.124966  ...   0.024360   0.018253
# MARRIAGE   0.016416  0.024036  0.003675  0.003836  ...  -0.027985  -0.040211
# AGE       -0.026144 -0.030219 -0.017858 -0.018790  ...   0.078767   0.071235
# PAY_1      0.663725  0.586904  0.563806  0.543924  ...   0.162684   0.172668
# PAY_2      1.000000  0.783850  0.668401  0.631858  ...   0.223744   0.234332
# PAY_3      0.783850  1.000000  0.778557  0.692950  ...   0.220336   0.224729
# PAY_4      0.668401  0.778557  1.000000  0.827182  ...   0.231816   0.231200
# PAY_5      0.631858  0.692950  0.827182  1.000000  ...   0.260935   0.261860
# PAY_6      0.585133  0.661049  0.720831  0.821514  ...   0.240796   0.276853
# BILL_AMT1  0.231630  0.207131  0.203356  0.201174  ...   0.837614   0.818139
# BILL_AMT2  0.239388  0.235299  0.223769  0.226417  ...   0.879002   0.855531
# BILL_AMT3  0.195458  0.200171  0.210223  0.202304  ...   0.816287   0.784147
# BILL_AMT4  0.223744  0.220336  0.231816  0.260935  ...   1.000000   0.935237
# BILL_AMT5  0.234332  0.224729  0.231200  0.261860  ...   0.935237   1.000000
# BILL_AMT6  0.221801  0.226693  0.238194  0.255678  ...   0.900000   0.943723
# PAY_AMT1  -0.070552  0.003017 -0.011717  0.014535  ...   0.267991   0.232498
# PAY_AMT2  -0.054281 -0.039868 -0.010464 -0.024628  ...   0.112888   0.093567
# PAY_AMT3  -0.065279 -0.060349 -0.077901  0.001205  ...   0.352174   0.291920
# PAY_AMT4  -0.031956 -0.043516 -0.049750 -0.063962  ...   0.057356   0.256713
# PAY_AMT5  -0.046379 -0.028618 -0.010810 -0.029210  ...   0.181344   0.163989
# PAY_AMT6  -0.029939 -0.051023 -0.030008 -0.025179  ...   0.159888   0.157867
# def_pay    0.259395  0.256291  0.233537  0.239179  ...  -0.007915   0.009532
#
#            BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# LIMIT_BAL   0.287902  0.230001  0.132230  0.230072  0.202773  0.205445
# SEX        -0.000037  0.022765  0.024393  0.015070  0.057347 -0.006160
# EDUCATION   0.019900 -0.044262 -0.035723 -0.024643 -0.037671 -0.040294
# MARRIAGE   -0.033541 -0.005228 -0.030449 -0.009521 -0.045708 -0.015015
# AGE         0.062059  0.052923  0.012226  0.070831  0.017653  0.019201
# PAY_1       0.171040 -0.084565 -0.067116 -0.081663 -0.071623 -0.063980
# PAY_2       0.221801 -0.070552 -0.054281 -0.065279 -0.031956 -0.046379
# PAY_3       0.226693  0.003017 -0.039868 -0.060349 -0.043516 -0.028618
# PAY_4       0.238194 -0.011717 -0.010464 -0.077901 -0.049750 -0.010810
# PAY_5       0.255678  0.014535 -0.024628  0.001205 -0.063962 -0.029210
# PAY_6       0.266104  0.006383 -0.014634 -0.000982  0.017828 -0.044826
# BILL_AMT1   0.784725  0.210185  0.041353  0.100700  0.121952  0.145261
# BILL_AMT2   0.825336  0.282985  0.039679  0.103562  0.106947  0.151671
# BILL_AMT3   0.806272  0.209422  0.531461  0.129035  0.142344  0.366348
# BILL_AMT4   0.900000  0.267991  0.112888  0.352174  0.057356  0.181344
# BILL_AMT5   0.943723  0.232498  0.093567  0.291920  0.256713  0.163989
# BILL_AMT6   1.000000  0.199835  0.183942  0.271243  0.201145  0.321583
# PAY_AMT1    0.199835  1.000000  0.087114  0.275067  0.093699  0.127490
# PAY_AMT2    0.183942  0.087114  1.000000  0.171740  0.148108  0.527288
# PAY_AMT3    0.271243  0.275067  0.171740  1.000000  0.159847  0.216437
# PAY_AMT4    0.201145  0.093699  0.148108  0.159847  1.000000  0.143381
# PAY_AMT5    0.321583  0.127490  0.527288  0.216437  0.143381  1.000000
# PAY_AMT6    0.124382  0.143174  0.070728  0.092809  0.088853  0.086489
# def_pay     0.011310 -0.076436 -0.035299 -0.073593 -0.052392 -0.050166
#
#            PAY_AMT6   def_pay
# LIMIT_BAL  0.230646 -0.178870
# SEX        0.012487 -0.046211
# EDUCATION -0.057705  0.018963
# MARRIAGE   0.007395  0.017195
# AGE       -0.013341 -0.015071
# PAY_1     -0.068690  0.333589
# PAY_2     -0.029939  0.259395
# PAY_3     -0.051023  0.256291
# PAY_4     -0.030008  0.233537
# PAY_5     -0.025179  0.239179
# PAY_6     -0.011734  0.216914
# BILL_AMT1  0.181762 -0.018013
# BILL_AMT2  0.175121 -0.007221
# BILL_AMT3  0.158073 -0.001527
# BILL_AMT4  0.159888 -0.007915
# BILL_AMT5  0.157867  0.009532
# BILL_AMT6  0.124382  0.011310
# PAY_AMT1   0.143174 -0.076436
# PAY_AMT2   0.070728 -0.035299
# PAY_AMT3   0.092809 -0.073593
# PAY_AMT4   0.088853 -0.052392
# PAY_AMT5   0.086489 -0.050166
# PAY_AMT6   1.000000 -0.057499
# def_pay   -0.057499  1.000000
#
# [24 rows x 24 columns]

# %%
g=sns.countplot(x="MARRIAGE", data=credit,hue="def_pay")

# %%
g=sns.countplot(x="EDUCATION", data=credit,hue="def_pay")

# %%
#Correlation Plotted
sns.heatmap(corrMat, square=True, annot=True, fmt=".1f", cmap=plt.cm.Reds)

# %%
#Covariance Estimation
covMat = credit.cov()
print(covMat)
# Out:
#               LIMIT_BAL          SEX     EDUCATION     MARRIAGE  \
# LIMIT_BAL  1.731828e+10  2625.837919 -20922.186093 -9472.611306
# SEX        2.625838e+03     0.239511      0.005644    -0.010170
# EDUCATION -2.092219e+04     0.005644      0.637710    -0.057444
# MARRIAGE  -9.472611e+03    -0.010170     -0.057444     0.267109
# AGE        1.670877e+05    -0.373861      1.178415    -1.917649
# PAY_1     -3.994526e+04    -0.045249      0.106452     0.014105
# PAY_2     -4.425436e+04    -0.068519      0.130706     0.009872
# PAY_3     -4.613548e+04    -0.055789      0.122175     0.014630
# PAY_4     -4.215235e+04    -0.054588      0.124751     0.002216
# PAY_5     -3.836793e+04    -0.066783      0.113307     0.002251
# PAY_6     -3.772246e+04    -0.046007      0.092062     0.004462
# BILL_AMT1  3.173152e+09  -731.554952   2934.762332 -1148.239902
# BILL_AMT2  2.775763e+09  -541.445836   2639.622073 -1005.036016
# BILL_AMT3  2.888311e+09   -80.339765   1705.529420 -1498.181166
# BILL_AMT4  2.610975e+09  -343.954564   1280.549313  -952.080043
# BILL_AMT5  2.487982e+09   225.013649    902.701493 -1286.993227
# BILL_AMT6  2.291140e+09    -1.080491    960.997298 -1048.271571
# PAY_AMT1   3.954553e+08   145.558045   -461.803011   -35.303534
# PAY_AMT2   6.986114e+08   479.267801  -1145.285726  -631.793502
# PAY_AMT3   6.624860e+08   161.376646   -430.593339  -107.666603
# PAY_AMT4   4.322352e+08   454.603981   -487.283337  -382.640613
# PAY_AMT5   4.447161e+08   -49.585670   -529.281143  -127.643159
# PAY_AMT6   6.468262e+08   130.229148   -982.003343    81.446421
# def_pay   -9.745460e+03    -0.009363      0.006270     0.003679
#
#                      AGE         PAY_1         PAY_2         PAY_3  \
# LIMIT_BAL  167087.693847 -39945.260130 -44254.364682 -46135.480240
# SEX            -0.373861     -0.045249     -0.068519     -0.055789
# EDUCATION       1.178415      0.106452      0.130706      0.122175
# MARRIAGE       -1.917649      0.014105      0.009872      0.014630
# AGE            83.629051     -0.442000     -0.278206     -0.325452
# PAY_1          -0.442000      1.218509      0.852533      0.762984
# PAY_2          -0.278206      0.852533      1.353995      1.074176
# PAY_3          -0.325452      0.762984      1.074176      1.386973
# PAY_4          -0.190541      0.726145      0.907453      1.069801
# PAY_5          -0.195098      0.681716      0.834792      0.926588
# PAY_6          -0.268558      0.637155      0.794225      0.908130
# BILL_AMT1   37548.929058  14337.774629  20666.295320  18704.182015
# BILL_AMT2   37616.682880  14338.908665  20323.157002  20217.820318
# BILL_AMT3   41364.514587  11740.622254  17855.125615  18507.020528
# BILL_AMT4   47416.330926  11821.299990  17138.253353  17081.508396
# BILL_AMT5   40342.024624  11803.621168  16886.019171  16390.105240
# BILL_AMT6   34319.200614  11417.358646  15607.255132  16144.600402
# PAY_AMT1     6323.207537  -1219.612074  -1072.583349     46.417223
# PAY_AMT2     4488.496510  -2974.379620  -2535.760457  -1885.010231
# PAY_AMT3    14172.910443  -1972.416965  -1662.052887  -1555.115645
# PAY_AMT4     2614.845760  -1280.625012   -602.307974   -830.114364
# PAY_AMT5     2888.288179  -1161.700184   -887.697838   -554.388190
# PAY_AMT6    -2599.936387  -1615.836308   -742.405266  -1280.541058
# def_pay        -0.057060      0.152454      0.124963      0.124963
#
#                   PAY_4         PAY_5  ...     BILL_AMT4     BILL_AMT5  \
# LIMIT_BAL -42152.351176 -38367.933967  ...  2.610975e+09  2.487982e+09
# SEX           -0.054588     -0.066783  ... -3.439546e+02  2.250136e+02
# EDUCATION      0.124751      0.113307  ...  1.280549e+03  9.027015e+02
# MARRIAGE       0.002216      0.002251  ... -9.520800e+02 -1.286993e+03
# AGE           -0.190541     -0.195098  ...  4.741633e+04  4.034202e+04
# PAY_1          0.726145      0.681716  ...  1.182130e+04  1.180362e+04
# PAY_2          0.907453      0.834792  ...  1.713825e+04  1.688602e+04
# PAY_3          1.069801      0.926588  ...  1.708151e+04  1.639011e+04
# PAY_4          1.361312      1.095798  ...  1.780445e+04  1.670534e+04
# PAY_5          1.095798      1.289145  ...  1.950242e+04  1.841230e+04
# PAY_6          0.981055      1.088044  ...  1.848995e+04  1.999947e+04
# BILL_AMT1  18192.678829  17513.852301  ...  4.227756e+09  3.884856e+09
# BILL_AMT2  19048.398558  18756.049650  ...  4.221594e+09  3.865487e+09
# BILL_AMT3  19255.737114  18032.521511  ...  4.218429e+09  3.812303e+09
# BILL_AMT4  17804.446065  19502.422586  ...  4.333231e+09  3.812549e+09
# BILL_AMT5  16705.343990  18412.296148  ...  3.812549e+09  3.835094e+09
# BILL_AMT6  16806.017330  17554.912206  ...  3.582638e+09  3.534167e+09
# PAY_AMT1    -178.607054    215.610680  ...  2.304844e+08  1.881142e+08
# PAY_AMT2    -490.138026  -1122.609055  ...  2.983367e+08  2.326296e+08
# PAY_AMT3   -1988.767302     29.945473  ...  5.072507e+08  3.955592e+08
# PAY_AMT4    -940.214452  -1176.337794  ...  6.115643e+07  2.575091e+08
# PAY_AMT5    -207.465930   -545.529140  ...  1.963559e+08  1.670469e+08
# PAY_AMT6    -746.109233   -609.225238  ...  2.242904e+08  2.083379e+08
# def_pay        0.112810      0.112431  ... -2.157168e+02  2.443986e+02
#
#               BILL_AMT6      PAY_AMT1      PAY_AMT2      PAY_AMT3  \
# LIMIT_BAL  2.291140e+09  3.954553e+08  6.986114e+08  6.624860e+08
# SEX       -1.080491e+00  1.455580e+02  4.792678e+02  1.613766e+02
# EDUCATION  9.609973e+02 -4.618030e+02 -1.145286e+03 -4.305933e+02
# MARRIAGE  -1.048272e+03 -3.530353e+01 -6.317935e+02 -1.076666e+02
# AGE        3.431920e+04  6.323208e+03  4.488497e+03  1.417291e+04
# PAY_1      1.141736e+04 -1.219612e+03 -2.974380e+03 -1.972417e+03
# PAY_2      1.560726e+04 -1.072583e+03 -2.535760e+03 -1.662053e+03
# PAY_3      1.614460e+04  4.641722e+01 -1.885010e+03 -1.555116e+03
# PAY_4      1.680602e+04 -1.786071e+02 -4.901380e+02 -1.988767e+03
# PAY_5      1.755491e+04  2.156107e+02 -1.122609e+03  2.994547e+01
# PAY_6      1.877095e+04  9.728647e+01 -6.853109e+02 -2.505932e+01
# BILL_AMT1  3.638577e+09  2.105600e+08  1.272983e+08  1.689459e+08
# BILL_AMT2  3.641379e+09  2.697486e+08  1.162229e+08  1.653260e+08
# BILL_AMT3  3.827701e+09  2.148021e+08  1.675051e+09  2.216515e+08
# BILL_AMT4  3.582638e+09  2.304844e+08  2.983367e+08  5.072507e+08
# BILL_AMT5  3.534167e+09  1.881142e+08  2.326296e+08  3.955592e+08
# BILL_AMT6  3.656865e+09  1.578851e+08  4.465709e+08  3.588997e+08
# PAY_AMT1   1.578851e+08  1.706985e+08  4.569405e+07  7.863451e+07
# PAY_AMT2   4.465709e+08  4.569405e+07  1.611792e+09  1.508636e+08
# PAY_AMT3   3.588997e+08  7.863451e+07  1.508636e+08  4.787618e+08
# PAY_AMT4   1.970244e+08  1.982936e+07  9.631398e+07  5.665267e+07
# PAY_AMT5   3.198764e+08  2.739833e+07  3.482064e+08  7.789789e+07
# PAY_AMT6   1.602878e+08  3.986302e+07  6.051139e+07  4.327543e+07
# def_pay    2.831648e+02 -4.134532e+02 -5.867206e+02 -6.666653e+02
#
#                PAY_AMT4      PAY_AMT5      PAY_AMT6      def_pay
# LIMIT_BAL  4.322352e+08  4.447161e+08  6.468262e+08 -9745.460230
# SEX        4.546040e+02 -4.958567e+01  1.302291e+02    -0.009363
# EDUCATION -4.872833e+02 -5.292811e+02 -9.820033e+02     0.006270
# MARRIAGE  -3.826406e+02 -1.276432e+02  8.144642e+01     0.003679
# AGE        2.614846e+03  2.888288e+03 -2.599936e+03    -0.057060
# PAY_1     -1.280625e+03 -1.161700e+03 -1.615836e+03     0.152454
# PAY_2     -6.023080e+02 -8.876978e+02 -7.424053e+02     0.124963
# PAY_3     -8.301144e+02 -5.543882e+02 -1.280541e+03     0.124963
# PAY_4     -9.402145e+02 -2.074659e+02 -7.461092e+02     0.112810
# PAY_5     -1.176338e+03 -5.455291e+02 -6.092252e+02     0.112431
# PAY_6      3.368454e+02 -8.600960e+02 -2.916757e+02     0.104756
# BILL_AMT1  1.514631e+08  1.832075e+08  2.969981e+08  -571.827498
# BILL_AMT2  1.263885e+08  1.820198e+08  2.722757e+08  -218.116146
# BILL_AMT3  1.810086e+08  4.730758e+08  2.644529e+08   -49.625430
# BILL_AMT4  6.115643e+07  1.963559e+08  2.242904e+08  -215.716821
# BILL_AMT5  2.575091e+08  1.670469e+08  2.083379e+08   244.398572
# BILL_AMT6  1.970244e+08  3.198764e+08  1.602878e+08   283.164801
# PAY_AMT1   1.982936e+07  2.739833e+07  3.986302e+07  -413.453201
# PAY_AMT2   9.631398e+07  3.482064e+08  6.051139e+07  -586.720575
# PAY_AMT3   5.665267e+07  7.789789e+07  4.327543e+07  -666.665306
# PAY_AMT4   2.623700e+08  3.820189e+07  3.067028e+07  -351.345306
# PAY_AMT5   3.820189e+07  2.705637e+08  3.031684e+07  -341.628018
# PAY_AMT6   3.067028e+07  3.031684e+07  4.541297e+08  -507.296581
# def_pay   -3.513453e+02 -3.416280e+02 -5.072966e+02     0.171405
#
# [24 rows x 24 columns]

# %%
#Covariance Plotted
pylab.rcParams['figure.figsize'] = (15.0, 20.0)
sns.heatmap(covMat,  square=True, annot=True, cmap=plt.cm.Reds)
pylab.rcParams['figure.figsize'] = (15.0, 12.0)

# %%
sns.jointplot(x='LIMIT_BAL',y='AGE',data=credit,kind="scatter")

# %% [markdown]
# ## Pre-process

# %% [markdown]
# #consolidate others in Education
# fil = (credit.EDUCATION == 5) | (credit.EDUCATION == 6) | (credit.EDUCATION == 0)
# credit.loc[fil, 'EDUCATION'] = 4
# credit.EDUCATION.value_counts()

# %% [markdown]
# #assume 0 value to be single for Marriage attribute
# credit.loc[credit.MARRIAGE == 0, 'MARRIAGE'] = 2
# credit.MARRIAGE.value_counts()

# %%
#null values removed if any
x = credit.isnull()
x.describe()
credit.dropna()
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# ID
# 10748     310000    1          3         1   32      0      0      0      0
# 12574      10000    2          3         1   49     -1     -1     -2     -1
# 29677      50000    1          2         1   28     -1     -1     -1      0
# 8857       80000    2          3         1   52      2      2      3      3
# 21099     270000    1          1         2   34      1      2      0      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 23296     160000    2          1         2   25     -1      0     -1     -1
# 15149     250000    1          1         1   53     -2     -2     -2     -2
# 18667      50000    2          1         2   23     -1     -1     -2     -2
# 3416      200000    2          2         1   37      0      0      0      0
# 18715     420000    2          1         2   28      0      0     -1      0
#
#        PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ID            ...
# 10748      0  ...      84373      57779      14163      8295      6000
# 12574      2  ...       1690       1138        930         0         0
# 29677     -1  ...      45975       1300      43987         0     46257
# 8857       3  ...      40748      39816      40607      3700      1600
# 21099      2  ...      22448      15490      17343         0      4000
# ...      ...  ...        ...        ...        ...       ...       ...
# 23296      0  ...       2199      10856          0      1000     11426
# 15149     -2  ...          0          0          0         0         0
# 18667     -2  ...          0          0          0         0         0
# 3416       0  ...     191730     171269     151550      8017      8000
# 18715      0  ...      65592      57438      31029      1010     64513
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  def_pay
# ID
# 10748      4000      3000      1000      2000        0
# 12574      2828         0       182         0        1
# 29677      2200      1300     43987      1386        0
# 8857       1600         0      1600      1600        1
# 21099      2000         0      2000      2000        0
# ...         ...       ...       ...       ...      ...
# 23296      2199     10000         0      9867        0
# 15149         0         0         0         0        1
# 18667         0         0         0         0        0
# 3416       8000      9000      7000      6000        0
# 18715      2420      1473      1062      1022        0
#
# [2000 rows x 24 columns]

# %% [markdown]
# Also due to some covariance to Bill Amount and Correlation of BILL_AMT attributes, part of the BILL_AMT columns were removed.

# %%
credit = credit.drop('BILL_AMT2',1)
credit = credit.drop('BILL_AMT4',1)
credit = credit.drop('BILL_AMT6',1)

# %% [markdown]
# ## Selecting and Dividing the data

# %%
## Train and Test models

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 10748 to 18715
# Data columns (total 21 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   LIMIT_BAL  2000 non-null   int64
#  1   SEX        2000 non-null   int64
#  2   EDUCATION  2000 non-null   int64
#  3   MARRIAGE   2000 non-null   int64
#  4   AGE        2000 non-null   int64
#  5   PAY_1      2000 non-null   int64
#  6   PAY_2      2000 non-null   int64
#  7   PAY_3      2000 non-null   int64
#  8   PAY_4      2000 non-null   int64
#  9   PAY_5      2000 non-null   int64
#  10  PAY_6      2000 non-null   int64
#  11  BILL_AMT1  2000 non-null   int64
#  12  BILL_AMT3  2000 non-null   int64
#  13  BILL_AMT5  2000 non-null   int64
#  14  PAY_AMT1   2000 non-null   int64
#  15  PAY_AMT2   2000 non-null   int64
#  16  PAY_AMT3   2000 non-null   int64
#  17  PAY_AMT4   2000 non-null   int64
#  18  PAY_AMT5   2000 non-null   int64
#  19  PAY_AMT6   2000 non-null   int64
#  20  def_pay    2000 non-null   int64
# dtypes: int64(21)
# memory usage: 423.8 KB

# %%
#dependant and independant variables
features = credit.iloc[:,:-1].values
depVar = credit.iloc[:,-1].values

# %%
print(features)
# Out:
# [[310000      1      3 ...   3000   1000   2000]
#  [ 10000      2      3 ...      0    182      0]
#  [ 50000      1      2 ...   1300  43987   1386]
#  ...
#  [ 50000      2      1 ...      0      0      0]
#  [200000      2      2 ...   9000   7000   6000]
#  [420000      2      1 ...   1473   1062   1022]]

# %%
print(depVar)
# Out:
# [0 1 0 ... 0 0 0]

# %%
y_train = depVar

# %%
X_train = features

# %%
#split
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train,test_size = 0.3,random_state = 1)
X_train.shape, X_test.shape
# Out:
# ((1400, 20), (600, 20))

# %%
y_train.shape, y_test.shape
# Out:
# ((1400,), (600,))

# %%
y_train
# Out:
# array([0, 0, 1, ..., 0, 0, 0], dtype=int64)

# %%
X_train
# Out:
# array([[100000,      1,      1, ...,      0,   2712,      0],
#        [130000,      2,      2, ...,      0,      0,      0],
#        [340000,      1,      2, ...,  11610,   5000,   2971],
#        ...,
#        [ 50000,      2,      2, ...,      0,      0,      0],
#        [100000,      1,      2, ...,    480,    390,    390],
#        [ 50000,      1,      2, ...,    430,    350,   3581]], dtype=int64)

# %% [markdown]
# ## Classifiers

# %% [markdown]
# ## Random Forest Classifier with tuning

# %%
#import and define RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators = 100,criterion = 'entropy',random_state = 0)

# %%
#Grid search for tuning
param_grid_rf = {'n_estimators': [200, 400, 600], 
              'class_weight' : ['balanced',None]}
grid_search_rf = GridSearchCV(estimator=rfc,param_grid=param_grid_rf,scoring='accuracy',cv=5,n_jobs=-1)
grid_search_rf = grid_search_rf.fit(X_train,y_train)

# %%
#Accuray on Cross Validation
best_accuracy_1 = grid_search_rf.best_score_
print('Accuracy on Cross Validation set :',best_accuracy_1)
# Out:
# Accuracy on Cross Validation set : 0.8221428571428572

# %%
#tuned parameters
best_parameters = grid_search_rf.best_params_
best_parameters
# Out:
# {'class_weight': None, 'n_estimators': 200}

# %%
#Make Predictions
pred_rf = grid_search_rf.predict(X_test)
predRsquared = r2_score(y_test,pred_rf)
rmse = sqrt(mean_squared_error(y_test, pred_rf))
print('R Squared: %.3f' % predRsquared)
print('RMSE: %.3f' % rmse)
# Out:
# R Squared: -0.099
# RMSE: 0.428

# %%
plt.scatter(y_test, pred_rf, alpha = 0.5)
plt.xlabel('Ground Truth')
plt.ylabel('Predictions')
plt.show();

# %%
acc = accuracy_score(y_test, pred_rf)
print('Accuracy: %.3f' % acc)
# Out:
# Accuracy: 0.817

# %% [markdown]
# ## Decision Tree Classification

# %%
from sklearn.tree import DecisionTreeClassifier
dct = DecisionTreeClassifier(criterion = 'entropy',random_state = 0)

# %%
dct.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=0, splitter='best')

# %%
y_pred = dct.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[392,  81],
#        [ 76,  51]], dtype=int64)

# %%
predRsquared = r2_score(y_test,y_pred)
rmse = sqrt(mean_squared_error(y_test, y_pred))
print('R Squared: %.3f' % predRsquared)
print('RMSE: %.3f' % rmse)
# Out:
# R Squared: -0.568
# RMSE: 0.512

# %%
acc = accuracy_score(y_test, y_pred)
print('Accuracy: %.3f' % acc)
# Out:
# Accuracy: 0.738

# %%
plt.scatter(y_test, y_pred, alpha = 0.5)
plt.xlabel('Ground Truth')
plt.ylabel('Predictions')
plt.show();

# %% [markdown]
# ## SVC Classification with gridsearch

# %%
from sklearn.svm import SVC
svc = SVC(kernel='linear', 
          class_weight='balanced')

# %%
from sklearn.model_selection  import GridSearchCV
svc = SVC(class_weight='balanced', random_state=1)
search_space = {'C': np.logspace(-3, 3, 7)}
gridsearch = GridSearchCV(svc, 
                          param_grid=search_space, 
                          scoring='accuracy', 
                          refit=True, cv=10)
gridsearch.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight='balanced', coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=1, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': array([1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='accuracy', verbose=0)

# %%
cv = gridsearch.best_score_
test_score = gridsearch.score(X_train, y_train)
best_c =  gridsearch.best_params_['C']

# %%
print('CV accuracy score: %0.3f' % cv)
print('Test accuracy score: %0.3f' % test_score)
print('Best C parameter: %0.1f' % best_c)
# Out:
# CV accuracy score: 0.730
# Test accuracy score: 0.777
# Best C parameter: 0.0

# %%
#Make Predictions
pred_svc = gridsearch.predict(X_test)
predRsquared = r2_score(y_test,pred_rf)
rmse = sqrt(mean_squared_error(y_test, pred_svc))
print('R Squared: %.3f' % predRsquared)
print('RMSE: %.3f' % rmse)
# Out:
# R Squared: -0.099
# RMSE: 0.460

# %%
acc = accuracy_score(y_test, pred_svc)
print('Accuracy: %.3f' % acc)
# Out:
# Accuracy: 0.788

# %% [markdown]
# ## Random Forest, Decision Tree and Support Vector Machine comparions

# %% [markdown]
# Random Forest gives the best model Accuracy value of 0.817. Also has the lowest RMSE with 0.428 value.

# %% [markdown]
# Smaller sample size was chosen to small due to the constraints of computer processing power. Expanding the sample size we might see better results.
